# %%
# !mkdir .kaggle

# %%
import json
token = {"username": "triinutasa", "key": "4a7a5d4822995fecb84bb6c4574082cb"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json
# Out:
# cp: cannot create regular file '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle config set -n path -v"/content"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

import matplotlib.pyplot as plt
import numpy as np

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

AUTOTUNE = tf.data.experimental.AUTOTUNE
    
print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.3.0

# %%
GCS_PATH='/content/gdrive/My Drive/gan-getting-started'
MONET_DIR = GCS_PATH + '/monet_jpg/*.jpg'
MONET_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/monet_jpg/*.jpg'))
print('Monet TFRecord Files:', len(MONET_FILENAMES))

PHOTO_DIR = GCS_PATH + '/photo_jpg/*.jpg'
PHOTO_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/photo_jpg/*.jpg'))
print('Photo TFRecord Files:', len(PHOTO_FILENAMES))

print(MONET_FILENAMES)
# Out:
# Monet TFRecord Files: 300
# Photo TFRecord Files: 6108
# ['/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_79.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_68.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_1.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_268.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_101.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_224.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_230.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_35.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_190.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_233.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_228.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_157.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_290.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_179.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_226.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_2.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_235.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_257.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_124.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_201.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_135.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_223.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_46.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_246.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_90.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_168.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_112.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_227.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_13.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_146.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_231.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_24.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_113.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_229.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_212.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_279.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_57.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_232.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_234.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_269.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_238.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_283.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_261.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_273.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_282.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_270.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_263.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_277.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_281.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_272.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_253.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_244.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_266.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_243.jpg', '/content/gdrive/My Drive/gan-getting-started/monet_jpg/MONET_245.jpg', '/content/gdrive/My Drive/gan-getting-started/monet ...

# %%
IMAGE_SIZE = [256, 256]
BATCH_SIZE = 5
class_names = ['monet_jpg', 'photo_jpg']

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = (tf.cast(image, tf.float32) / 127.5) - 1
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_tfrec(example['image'])
    return image

def process_path(file_path):
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_image(img)
  return img

# %%
def load_dataset(filenames, labeled=True, ordered=False):
    dataset = tf.data.Dataset.list_files(str(filenames), shuffle=False)
    dataset = dataset.map(process_path, num_parallel_calls=AUTOTUNE)
    return dataset

# %%
monet_ds = load_dataset(MONET_DIR, labeled=True).batch(1)
photo_ds = load_dataset(PHOTO_DIR, labeled=True).batch(1)
example_monet = next(iter(monet_ds))
example_photo = next(iter(photo_ds))

# %%
plt.subplot(122)
plt.title('Monet')
plt.imshow(tf.squeeze(example_monet[0] * 0.5 + 0.5))

plt.subplot(121)
plt.title('Photo')
plt.imshow(tf.squeeze(example_photo[0] * 0.5 + 0.5))

# %%
OUTPUT_CHANNELS = 3

def downsample(filters, size, apply_instancenorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2D(filters, size, strides=2, padding='same', data_format="channels_last",
                             kernel_initializer=initializer, use_bias=False))

    if apply_instancenorm:
        result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    result.add(layers.LeakyReLU())

    return result

# %%
def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=initializer,
                                      use_bias=False))

    result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    if apply_dropout:
        result.add(layers.Dropout(0.5))

    result.add(layers.ReLU())

    return result

# %%
def Generator():
    inputs = layers.Input(shape=[256,256,3])


    # bs = batch size
    down_stack = [
        downsample(64, 4, apply_instancenorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh') # (bs, 256, 256, 3)

    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)
        
    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])
        
    x = last(x)
    return keras.Model(inputs=inputs, outputs=x)

# %%
def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    inp = layers.Input(shape=[256, 256, 3], name='input_image')

    x = inp

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = layers.Conv2D(512, 4, strides=1,
                         kernel_initializer=initializer,
                         use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    norm1 = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(conv)

    leaky_relu = layers.LeakyReLU()(norm1)

    zero_pad2 = layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = layers.Conv2D(1, 4, strides=1,
                         kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=inp, outputs=last)

# %%
# with strategy.scope():
monet_generator = Generator() # transforms photos to Monet-esque paintings
photo_generator = Generator() # transforms Monet paintings to be more like photos

monet_discriminator = Discriminator() # differentiates real Monet paintings and generated Monet paintings
photo_discriminator = Discriminator() # differentiates real photos and generated photos

# %%
test_gen = Generator()
# example_photo = tf.expand_dims(example_photo,0)

to_monet = tf.squeeze(test_gen(example_photo))
# to_monet = test_gen(example_photo)


plt.subplot(1, 2, 1)
plt.title("Original Photo")
plt.imshow(tf.squeeze(example_photo[0] * 0.5 + 0.5))
# plt.imshow(example_monet.numpy().astype("uint8"))

plt.subplot(1, 2, 2)
plt.title("Monet-esque Photo")
plt.imshow(to_monet)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class CycleGan(keras.Model):
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn
        
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
        # real_monet = tf.expand_dims(real_monet, 0)
        # real_photo = tf.expand_dims(real_photo, 0)
        
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)

        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %%
with strategy.scope():
    def discriminator_loss(real, generated):
        real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

        generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)

        total_disc_loss = real_loss + generated_loss

        return total_disc_loss * 0.5

# %%
with strategy.scope():
    def generator_loss(generated):
        return tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated), generated)

# %%
with strategy.scope():
    def calc_cycle_loss(real_image, cycled_image, LAMBDA):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

        return LAMBDA * loss1

# %%
with strategy.scope():
    def identity_loss(real_image, same_image, LAMBDA):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %%
with strategy.scope():
    monet_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

    monet_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
with strategy.scope():
    cycle_gan_model = CycleGan(
        monet_generator, photo_generator, monet_discriminator, photo_discriminator
    )

    cycle_gan_model.compile(
        m_gen_optimizer = monet_generator_optimizer,
        p_gen_optimizer = photo_generator_optimizer,
        m_disc_optimizer = monet_discriminator_optimizer,
        p_disc_optimizer = photo_discriminator_optimizer,
        gen_loss_fn = generator_loss,
        disc_loss_fn = discriminator_loss,
        cycle_loss_fn = calc_cycle_loss,
        identity_loss_fn = identity_loss
    )

# %%
#Create a model callback that saves the weights
checkpoint_path = "training_1/cp.ckpt"
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
cycle_gan_model.fit(
    tf.data.Dataset.zip((monet_ds, photo_ds)),
    epochs=25,
    callbacks=[cp_callback]
)
# Out:
# Epoch 1/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 5.1124 - photo_gen_loss: 5.2532 - monet_disc_loss: 0.6502 - photo_disc_loss: 0.6251
# Epoch 00001: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 207s 691ms/step - monet_gen_loss: 5.1100 - photo_gen_loss: 5.2481 - monet_disc_loss: 0.6497 - photo_disc_loss: 0.6253
# Epoch 2/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.5335 - photo_gen_loss: 3.6744 - monet_disc_loss: 0.6786 - photo_disc_loss: 0.6331
# Epoch 00002: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 143s 476ms/step - monet_gen_loss: 3.5342 - photo_gen_loss: 3.6741 - monet_disc_loss: 0.6785 - photo_disc_loss: 0.6331
# Epoch 3/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.4633 - photo_gen_loss: 3.6023 - monet_disc_loss: 0.6669 - photo_disc_loss: 0.6186
# Epoch 00003: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 474ms/step - monet_gen_loss: 3.4634 - photo_gen_loss: 3.6012 - monet_disc_loss: 0.6671 - photo_disc_loss: 0.6188
# Epoch 4/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3
25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7614 - photo_gen_loss: 2.8232 - monet_disc_loss: 0.6197 - photo_disc_loss: 0.6034
# Epoch 00016: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 472ms/step - monet_gen_loss: 2.7637 - photo_gen_loss: 2.8215 - monet_disc_loss: 0.6197 - photo_disc_loss: 0.6040
# Epoch 17/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7349 - photo_gen_loss: 2.8005 - monet_disc_loss: 0.6214 - photo_disc_loss: 0.6032
# Epoch 00017: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 473ms/step - monet_gen_loss: 2.7381 - photo_gen_loss: 2.7989 - monet_disc_loss: 0.6215 - photo_disc_loss: 0.6038
# Epoch 18/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7031 - photo_gen_loss: 2.7668 - monet_disc_loss: 0.6247 - photo_disc_loss: 0.6023
# Epoch 00018: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 473ms/step - monet_gen_loss: 2.7054 - photo_gen_loss: 2.7651 - monet_disc_loss: 0.6247 - photo_disc_loss: 0.6030
# Epoch 19/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6491 - photo_gen_loss: 2.7358 - monet_disc_loss: 0.6336 - photo_disc_loss: 0.6003
# Epoch 00019: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 473ms/step - monet_gen_loss: 2.6511 - photo_gen_loss: 2.7343 - monet_disc_loss: 0.6337 - photo_disc_loss: 0.6007
# Epoch 20/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6406 - photo_gen_loss: 2.7297 - monet_disc_loss: 0.6292 - photo_disc_loss: 0.5981
# Epoch 00020: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 473ms/step - monet_gen_loss: 2.6439 - photo_gen_loss: 2.7287 - monet_disc_loss: 0.6290 - photo_disc_loss: 0.5980
# Epoch 21/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6305 - photo_gen_loss: 2.7147 - monet_disc_loss: 0.6298 - photo_disc_loss: 0.5956
# Epoch 00021: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 473ms/step - monet_gen_loss: 2.6322 - photo_gen_loss: 2.7131 - monet_disc_loss: 0.6298 - photo_disc_loss: 0.5959
# Epoch 22/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6111 - photo_gen_loss: 2.6811 - monet_disc_loss: 0.6284 - photo_disc_loss: 0.6013
# Epoch 00022: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 473ms/step - monet_gen_loss: 2.6128 - photo_gen_loss: 2.6796 - monet_disc_loss: 0.6283 - photo_disc_loss: 0.6017
# Epoch 23/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5974 - photo_gen_loss: 2.6659 - monet_disc_loss: 0.6264 - photo_disc_loss: 0.6002
# Epoch 00023: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 472ms/step - monet_gen_loss: 2.5985 - photo_gen_loss: 2.6645 - monet_disc_loss: 0.6264 - photo_disc_loss: 0.6002
# Epoch 24/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5930 - photo_gen_loss: 2.6637 - monet_disc_loss: 0.6226 - photo_disc_loss: 0.5936
# Epoch 00024: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 473ms/step - monet_gen_loss: 2.5946 - photo_gen_loss: 2.6624 - monet_disc_loss: 0.6225 - photo_disc_loss: 0.5935
# Epoch 25/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5652 - photo_gen_loss: 2.6347 - monet_disc_loss: 0.6280 - photo_disc_loss: 0.5961
# Epoch 00025: saving model to training_1/cp.ckpt
# 300/300 [==============================] - 142s 472ms/step - monet_gen_loss: 2.5667 - photo_gen_loss: 2.6333 - monet_disc_loss: 0.6278 - photo_disc_loss: 0.5963

# %%
cycle_gan_model.save_weights('./checkpoints/my_checkpoint')

# %%
#Check the checkpoint files
checkpoint_dir = os.path.dirname(checkpoint_path)
# !ls {checkpoint_dir}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-c2461ba8d03b> in <module>()
#       1 #Check the checkpoint files
# ----> 2 checkpoint_dir = os.path.dirname(checkpoint_path)
#       3 get_ipython().system('ls {checkpoint_dir}')
#
# NameError: name 'os' is not defined

# %%
_, ax = plt.subplots(5, 2, figsize=(12, 12))
for i, img in enumerate(photo_ds.take(5)):
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()

# %%
# !cp -r /content/training_1 /content/gdrive/My\ Drive/gan-getting-started

# %%
# !gsutil -q -m cp -r gs://my-bucket-name drive /content/drive/My\ Drive/
