# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename)

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
import numpy as np

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

AUTOTUNE = tf.data.experimental.AUTOTUNE
    
print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.3.1
# /opt/conda/lib/python3.7/site-packages/tensorflow_addons/utils/ensure_tf_install.py:68: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.2.0 and strictly below 2.3.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.3.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   UserWarning,

# %%
GCS_PATH = KaggleDatasets().get_gcs_path()

# %%
# MONET_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/monet_jpg/*.jpg'))
MONET_FILENAMES = GCS_PATH + '/monet_jpg/*.jpg'

print('Monet JPG Files:', len(MONET_FILENAMES))

# PHOTO_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/photo_jpg/*.jpg'))
PHOTO_FILENAMES = GCS_PATH + '/photo_jpg/*.jpg'

print('Photo JPG Files:', len(PHOTO_FILENAMES))
# Out:
# Monet JPG Files: 81
# Photo JPG Files: 81

# %%
IMAGE_SIZE = [256, 256]
BATCH_SIZE = 5
class_names = ['monet_jpg', 'photo_jpg']

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = (tf.cast(image, tf.float32) / 127.5) - 1
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_tfrec(example['image'])
    return image

def process_path(file_path):
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_image(img)
  return img

# %%
def load_dataset(filenames, labeled=True, ordered=False):
    dataset = tf.data.Dataset.list_files(str(filenames), shuffle=False)
    dataset = dataset.map(process_path, num_parallel_calls=AUTOTUNE)
    return dataset

# %%
monet_ds = load_dataset(MONET_FILENAMES, labeled=True).batch(1)
photo_ds = load_dataset(PHOTO_FILENAMES, labeled=True).batch(1)
example_monet = next(iter(monet_ds))
example_photo = next(iter(photo_ds))

# %%
plt.subplot(122)
plt.title('Monet')
plt.imshow(tf.squeeze(example_monet[0] * 0.5 + 0.5))

plt.subplot(121)
plt.title('Photo')
plt.imshow(tf.squeeze(example_photo[0] * 0.5 + 0.5))

# %%
OUTPUT_CHANNELS = 3

def downsample(filters, size, apply_instancenorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2D(filters, size, strides=2, padding='same', data_format="channels_last",
                             kernel_initializer=initializer, use_bias=False))

    if apply_instancenorm:
        result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    result.add(layers.LeakyReLU())

    return result

# %%
def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=initializer,
                                      use_bias=False))

    result.add(tfa.layers.InstanceNormalization(gamma_initializer=gamma_init))

    if apply_dropout:
        result.add(layers.Dropout(0.5))

    result.add(layers.ReLU())

    return result

# %%
def Generator():
    inputs = layers.Input(shape=[256,256,3])


    # bs = batch size
    down_stack = [
        downsample(64, 4, apply_instancenorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh') # (bs, 256, 256, 3)

    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)
        
    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])
        
    x = last(x)
    return keras.Model(inputs=inputs, outputs=x)

# %%
def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    inp = layers.Input(shape=[256, 256, 3], name='input_image')

    x = inp

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = layers.Conv2D(512, 4, strides=1,
                         kernel_initializer=initializer,
                         use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    norm1 = tfa.layers.InstanceNormalization(gamma_initializer=gamma_init)(conv)

    leaky_relu = layers.LeakyReLU()(norm1)

    zero_pad2 = layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = layers.Conv2D(1, 4, strides=1,
                         kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=inp, outputs=last)

# %%
# with strategy.scope():
monet_generator = Generator() # transforms photos to Monet-esque paintings
photo_generator = Generator() # transforms Monet paintings to be more like photos

monet_discriminator = Discriminator() # differentiates real Monet paintings and generated Monet paintings
photo_discriminator = Discriminator() # differentiates real photos and generated photos

# %%
test_gen = Generator()
# example_photo = tf.expand_dims(example_photo,0)

to_monet = tf.squeeze(test_gen(example_photo))
# to_monet = test_gen(example_photo)


plt.subplot(1, 2, 1)
plt.title("Original Photo")
plt.imshow(tf.squeeze(example_photo[0] * 0.5 + 0.5))
# plt.imshow(example_monet.numpy().astype("uint8"))

plt.subplot(1, 2, 2)
plt.title("Monet-esque Photo")
plt.imshow(to_monet)
plt.show()

# %%
class CycleGan(keras.Model):
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn
        
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
        # real_monet = tf.expand_dims(real_monet, 0)
        # real_photo = tf.expand_dims(real_photo, 0)
        
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)

        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %%
with strategy.scope():
    def discriminator_loss(real, generated):
        real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

        generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)

        total_disc_loss = real_loss + generated_loss

        return total_disc_loss * 0.5

# %%
with strategy.scope():
    def generator_loss(generated):
        return tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated), generated)

# %%
with strategy.scope():
    def calc_cycle_loss(real_image, cycled_image, LAMBDA):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

        return LAMBDA * loss1

# %%
with strategy.scope():
    def identity_loss(real_image, same_image, LAMBDA):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %%
with strategy.scope():
    monet_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

    monet_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
with strategy.scope():
    cycle_gan_model = CycleGan(
        monet_generator, photo_generator, monet_discriminator, photo_discriminator
    )

    cycle_gan_model.compile(
        m_gen_optimizer = monet_generator_optimizer,
        p_gen_optimizer = photo_generator_optimizer,
        m_disc_optimizer = monet_discriminator_optimizer,
        p_disc_optimizer = photo_discriminator_optimizer,
        gen_loss_fn = generator_loss,
        disc_loss_fn = discriminator_loss,
        cycle_loss_fn = calc_cycle_loss,
        identity_loss_fn = identity_loss
    )

# %%
#Create a model callback that saves the weights
checkpoint_path = "training_3/cp.ckpt"
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
cycle_gan_model.fit(
    tf.data.Dataset.zip((monet_ds, photo_ds)),
    epochs=25,
    callbacks=[cp_callback]
)
# Out:
# Epoch 1/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 5.1853 - photo_gen_loss: 5.2563 - monet_disc_loss: 0.6241 - photo_disc_loss: 0.6270
# Epoch 00001: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 231s 768ms/step - monet_gen_loss: 5.1831 - photo_gen_loss: 5.2554 - monet_disc_loss: 0.6241 - photo_disc_loss: 0.6277
# Epoch 2/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.5209 - photo_gen_loss: 3.6511 - monet_disc_loss: 0.6805 - photo_disc_loss: 0.6145
# Epoch 00002: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 127s 424ms/step - monet_gen_loss: 3.5217 - photo_gen_loss: 3.6543 - monet_disc_loss: 0.6808 - photo_disc_loss: 0.6141
# Epoch 3/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.4358 - photo_gen_loss: 3.5585 - monet_disc_loss: 0.6570 - photo_disc_loss: 0.6218
# Epoch 00003: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 120s 401ms/step - monet_gen_loss: 3.4351 - photo_gen_loss: 3.5602 - monet_disc_loss: 0.6577 - photo_disc_loss: 0.6220
# Epoch 4/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.2292 - photo_gen_loss: 3.3465 - monet_disc_loss: 0.6501 - photo_disc_loss: 0.6147
# Epoch 00004: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 122s 406ms/step - monet_gen_loss: 3.2278 - photo_gen_loss: 3.3474 - monet_disc_loss: 0.6509 - photo_disc_loss: 0.6150
# Epoch 5/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 3.0757 - photo_gen_loss: 3.2018 - monet_disc_loss: 0.6412 - photo_disc_loss: 0.6037
# Epoch 00005: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 119s 396ms/step - monet_gen_loss: 3.0737 - photo_gen_loss: 3.2021 - monet_disc_loss: 0.6420 - photo_disc_loss: 0.6043
# Epoch 6/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9947 - photo_gen_loss: 3.1276 - monet_disc_loss: 0.6333 - photo_disc_loss: 0.5906
# Epoch 00006: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 117s 389ms/step - monet_gen_loss: 2.9925 - photo_gen_loss: 3.1272 - monet_disc_loss: 0.6342 - photo_disc_loss: 0.5919
# Epoch 7/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9755 - photo_gen_loss: 3.1048 - monet_disc_loss: 0.6278 - photo_disc_loss: 0.5933
# Epoch 00007: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 123s 410ms/step - monet_gen_loss: 2.9736 - photo_gen_loss: 3.1058 - monet_disc_loss: 0.6289 - photo_disc_loss: 0.5941
# Epoch 8/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9521 - photo_gen_loss: 3.0540 - monet_disc_loss: 0.6239 - photo_disc_loss: 0.5986
# Epoch 00008: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 125s 416ms/step - monet_gen_loss: 2.9500 - photo_gen_loss: 3.0550 - monet_disc_loss: 0.6250 - photo_disc_loss: 0.5990
# Epoch 9/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9333 - photo_gen_loss: 3.0212 - monet_disc_loss: 0.6204 - photo_disc_loss: 0.5997
# Epoch 00009: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 115s 384ms/step - monet_gen_loss: 2.9311 - photo_gen_loss: 3.0218 - monet_disc_loss: 0.6214 - photo_disc_loss: 0.6002
# Epoch 10/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.9041 - photo_gen_loss: 2.9835 - monet_disc_loss: 0.6163 - photo_disc_loss: 0.5967
# Epoch 00010: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 122s 408ms/step - monet_gen_loss: 2.9021 - photo_gen_loss: 2.9843 - monet_disc_loss: 0.6171 - photo_disc_loss: 0.5975
# Epoch 11/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.8759 - photo_gen_loss: 2.9410 - monet_disc_loss: 0.6123 - photo_disc_loss: 0.5976
# Epoch 00011: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 123s 410ms/step - monet_gen_loss: 2.8738 - photo_gen_loss: 2.9413 - monet_disc_loss: 0.6132 - photo_disc_loss: 0.5987
# Epoch 12/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.8443 - photo_gen_loss: 2.8933 - monet_disc_loss: 0.6093 - photo_disc_loss: 0.5975
# Epoch 00012: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 118s 392ms/step - monet_gen_loss: 2.8423 - photo_gen_loss: 2.8939 - monet_disc_loss: 0.6101 - photo_disc_loss: 0.5982
# Epoch 13/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.8087 - photo_gen_loss: 2.8434 - monet_disc_loss: 0.6073 - photo_disc_loss: 0.6007
# Epoch 00013: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 117s 390ms/step - monet_gen_loss: 2.8067 - photo_gen_loss: 2.8440 - monet_disc_loss: 0.6080 - photo_disc_loss: 0.6012
# Epoch 14/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7730 - photo_gen_loss: 2.7939 - monet_disc_loss: 0.6073 - photo_disc_loss: 0.6045
# Epoch 00014: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 118s 393ms/step - monet_gen_loss: 2.7710 - photo_gen_loss: 2.7943 - monet_disc_loss: 0.6079 - photo_disc_loss: 0.6050
# Epoch 15/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7366 - photo_gen_loss: 2.7580 - monet_disc_loss: 0.6092 - photo_disc_loss: 0.6051
# Epoch 00015: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 123s 409ms/step - monet_gen_loss: 2.7346 - photo_gen_loss: 2.7582 - monet_disc_loss: 0.6098 - photo_disc_loss: 0.6053
# Epoch 16/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.7037 - photo_gen_loss: 2.7365 - monet_disc_loss: 0.6149 - photo_disc_loss: 0.6071
# Epoch 00016: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 122s 406ms/step - monet_gen_loss: 2.7016 - photo_gen_loss: 2.7365 - monet_disc_loss: 0.6155 - photo_disc_loss: 0.6073
# Epoch 17/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6765 - photo_gen_loss: 2.7143 - monet_disc_loss: 0.6148 - photo_disc_loss: 0.6087
# Epoch 00017: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 119s 395ms/step - monet_gen_loss: 2.6746 - photo_gen_loss: 2.7144 - monet_disc_loss: 0.6153 - photo_disc_loss: 0.6088
# Epoch 18/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6491 - photo_gen_loss: 2.6899 - monet_disc_loss: 0.6153 - photo_disc_loss: 0.6074
# Epoch 00018: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 123s 409ms/step - monet_gen_loss: 2.6475 - photo_gen_loss: 2.6903 - monet_disc_loss: 0.6157 - photo_disc_loss: 0.6075
# Epoch 19/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.6418 - photo_gen_loss: 2.6873 - monet_disc_loss: 0.6160 - photo_disc_loss: 0.6071
# Epoch 00019: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 124s 414ms/step - monet_gen_loss: 2.6399 - photo_gen_loss: 2.6875 - monet_disc_loss: 0.6164 - photo_disc_loss: 0.6073
# Epoch 20/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5875 - photo_gen_loss: 2.6437 - monet_disc_loss: 0.6231 - photo_disc_loss: 0.6125
# Epoch 00020: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 120s 400ms/step - monet_gen_loss: 2.5858 - photo_gen_loss: 2.6438 - monet_disc_loss: 0.6235 - photo_disc_loss: 0.6125
# Epoch 21/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5397 - photo_gen_loss: 2.6212 - monet_disc_loss: 0.6298 - photo_disc_loss: 0.6120
# Epoch 00021: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 123s 409ms/step - monet_gen_loss: 2.5380 - photo_gen_loss: 2.6213 - monet_disc_loss: 0.6302 - photo_disc_loss: 0.6120
# Epoch 22/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5193 - photo_gen_loss: 2.5891 - monet_disc_loss: 0.6270 - photo_disc_loss: 0.6157
# Epoch 00022: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 117s 390ms/step - monet_gen_loss: 2.5178 - photo_gen_loss: 2.5897 - monet_disc_loss: 0.6272 - photo_disc_loss: 0.6155
# Epoch 23/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.4739 - photo_gen_loss: 2.5800 - monet_disc_loss: 0.6361 - photo_disc_loss: 0.6141
# Epoch 00023: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 118s 394ms/step - monet_gen_loss: 2.4732 - photo_gen_loss: 2.5824 - monet_disc_loss: 0.6363 - photo_disc_loss: 0.6135
# Epoch 24/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.5537 - photo_gen_loss: 2.6079 - monet_disc_loss: 0.6214 - photo_disc_loss: 0.6067
# Epoch 00024: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 115s 383ms/step - monet_gen_loss: 2.5517 - photo_gen_loss: 2.6093 - monet_disc_loss: 0.6217 - photo_disc_loss: 0.6061
# Epoch 25/25
# 300/300 [==============================] - ETA: 0s - monet_gen_loss: 2.4506 - photo_gen_loss: 2.5383 - monet_disc_loss: 0.6370 - photo_disc_loss: 0.6160
# Epoch 00025: saving model to training_3/cp.ckpt
# 300/300 [==============================] - 122s 406ms/step - monet_gen_loss: 2.4493 - photo_gen_loss: 2.5394 - monet_disc_loss: 0.6371 - photo_disc_loss: 0.6154

# %%
cycle_gan_model.save_weights('./checkpoints/my_checkpoint')

# %%
#Check the checkpoint files
#cycle_gan_model.load_weights('./checkpoints/my_checkpoint')
# cycle_gan_model.load_weights('/content/gdrive/My Drive/gan-getting-started/training_1/checkpoint')

# %%
_, ax = plt.subplots(5, 2, figsize=(12, 12))
for i, img in enumerate(photo_ds.take(5)):
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()

# %%
import PIL
! mkdir ../images

# %%
i = 1
for img in photo_ds:
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    im = PIL.Image.fromarray(prediction)
    im.save("../images/" + str(i) + ".jpg")
    i += 1

# %%
import shutil
shutil.make_archive("/kaggle/working/images", 'zip', "/kaggle/images")
# Out:
# '/kaggle/working/images.zip'

# %%
# !cp /kaggle/working/images.zip /kaggle/images.zip
